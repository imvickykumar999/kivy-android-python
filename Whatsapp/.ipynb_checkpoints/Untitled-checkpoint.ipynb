# %%
from kivymd.app import MDApp
from kivy.uix.floatlayout import FloatLayout
from kivymd.uix.tab import MDTabsBase
from kivymd.uix.list import TwoLineAvatarIconListItem
from kivymd.uix.list import ImageLeftWidget

class MainApp(MDApp):
    def on_start(self):
        # Set colors
        self.theme_cls.primary_palette = 'Green'
        self.theme_cls.primary_hue = '900'

        # Add messages
        self.new_message("ERIK SANDBERG", "Hello World", "woman.png")
        self.new_message("ERIK Danberg", "Hello World", "woman.png")
        self.new_message("Danny Erikberg", "Hello World", "woman.png")
        self.new_message("KivyMD NotSandberg", "Hello World", "woman.png")
        self.new_message("Whats App", "Hello World", "woman.png")
        self.new_message("Me Myself", "Hello World", "woman.png")
        self.new_message("Pewdiepie", "Hello World", "woman.png")

    def new_message(self, name, message, image_name):
        new_message = TwoLineAvatarIconListItem(text=name, secondary_text=message)
        new_message.add_widget(ImageLeftWidget(source=image_name))
        self.root.ids.list.add_widget(new_message)


    def on_tab_switch(
            self, instance_tabs, instance_tab, instance_tab_label, tab_text
    ):
        '''Called when switching tabs.

        :type instance_tabs: <kivymd.uix.tab.MDTabs object>;
        :param instance_tab: <__main__.Tab object>;
        :param instance_tab_label: <kivymd.uix.tab.MDTabsLabel object>;
        :param tab_text: text or name icon of tab;
        '''
        pass



class Tab(FloatLayout, MDTabsBase):
    '''Class implementing content for a tab.'''



MainApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Vicky\.kivy\logs\kivy_21-05-03_4.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\Vicky\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.8.3 (default, Jul  2 2020, 17:30:36) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Vicky\anaconda3\python.exe"
# [INFO   ] [Logger      ] Purge log fired. Analysing...
# [INFO   ] [Logger      ] Purge 29 log files
# [INFO   ] [Logger      ] Purge finished!
# [INFO   ] [KivyMD      ] v0.104.0
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.13596 Compatibility Profile Context 20.10.32 27.20.1032.2'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon(TM) Vega 8 Graphics'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [GL          ] NPOT texture support is available
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# kivy\properties.pyx in kivy.properties.ColorProperty.convert()
#
# kivy\properties.pyx in kivy.properties.ColorProperty.parse_list()
#
# ValueError: Invalid value for color (got [])
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\kivy\lang\builder.py in _apply_rule(self, widget, rule, rootrule, template_ctx, ignored_consts, rule_children)
#     700                                 key not in ignored_consts):
# --> 701                             setattr(widget_set, key, value)
#     702                     else:
#
# kivy\weakproxy.pyx in kivy.weakproxy.WeakProxy.__setattr__()
#
# kivy\properties.pyx in kivy.properties.Property.__set__()
#
# kivy\properties.pyx in kivy.properties.Property.set()
#
# kivy\properties.pyx in kivy.properties.ColorProperty.convert()
#
# ValueError: MDTabsLabel.color has an invalid format (got [])
#
# During handling of the above exception, another exception occurred:
#
# BuilderException                          Traceback (most recent call last)
# <ipython-input-1-a7705f1760ab> in <module>
#      45
#      46
# ---> 47 MainApp().run()
#
# ~\anaconda3\lib\site-packages\kivy\app.py in run(self)
#     947         '''Launches the app in standalone mode.
#     948         '''
# --> 949         self._run_prepare()
#     950         runTouchApp()
#     951         self.stop()
#
# ~\anaconda3\lib\site-packages\kivy\app.py in _run_prepare(self)
#     916         if not self.built:
#     917             self.load_config()
# --> 918             self.load_kv(filename=self.kv_file)
#     919             root = self.build()
#     920             if root:
#
# ~\anaconda3\lib\site-packages\kivy\app.py in load_kv(self, filename)
#     689             Logger.debug('App: kv <%s> not found' % filename)
#     690             return False
# --> 691         root = Builder.load_file(rfilename)
#     692         if root:
#     693             self.root = root
#
# ~\anaconda3\lib\site-packages\kivy\lang\builder.py in load_file(self, filename, encoding, **kwargs)
#     304         with open(filename, 'r', encoding=encoding) as fd:
#     305             data = fd.read()
# --> 306             return self.load_string(data, **kwargs)
#     307
#     308     def unload_file(self, filename):
#
# ~\anaconda3\lib\site-packages\kivy\lang\builder.py in load_string(self, string, **kwargs)
#     406                 widget.apply_class_lang_rules(
#     407                     root=widget, rule_children=rule_children)
# --> 408                 self._apply_rule(
#     409                     widget, parser.root, parser.root,
#     410                     rule_children=rule_children)
#
# ~\anaconda3\lib\site-packages\kivy\lang\builder.py in _apply_rule(self, widget, rule, rootrule, template_ctx, ignored_consts, rule_children)
#     661                 child.apply_class_lang_rules(
#     662                     root=rctx['ids']['root'], rule_children=rule_children)
# --> 663                 self._apply_rule(
#     664                     child, crule, rootrule, rule_children=rule_children)
#     665
#
# ~\anaconda3\lib\site-packages\kivy\lang\builder.py in _apply_rule(self, widget, rule, rootrule, template_ctx, ignored_consts, rule_children)
#     657                 # previous implementation was doing the add_widget() before
#     658                 # apply(), and so, we could use "self.parent".
# --> 659                 child = cls(__no_builder=True)
#     660                 widget.add_widget(child)
#     661                 child.apply_class_lang_rules(
#
# ~\anaconda3\lib\site-packages\kivy\uix\floatlayout.py in __init__(self, **kwargs)
#      63
#      64     def __init__(self, **kwargs):
# ---> 65         super(FloatLayout, self).__init__(**kwargs)
#      66         fbind = self.fbind
#      67         update = self._trigger_layout
#
# ~\anaconda3\lib\site-packages\kivy\uix\layout.py in __init__(self, **kwargs)
#      74         if self._trigger_layout is None:
#      75             self._trigger_layout = Clock.create_trigger(self.do_layout, -1)
# ---> 76         super(Layout, self).__init__(**kwargs)
#      77
#      78     def do_layout(self, *largs):
#
# ~\Desktop\Repository\kivy-android-python\Whatsapp\kivymd\uix\tab.py in __init__(self, **kwargs)
#     380
#     381     def __init__(self, **kwargs):
# --> 382         self.tab_label = MDTabsLabel(tab=self)
#     383         super().__init__(**kwargs)
#     384
#
# ~\Desktop\Repository\kivy-android-python\Whatsapp\kivymd\uix\tab.py in __init__(self, **kwargs)
#     334
#     335     def __init__(self, **kwargs):
# --> 336         super().__init__(**kwargs)
#     337         self.min_space = 0
#     338
#
# ~\anaconda3\lib\site-packages\kivy\uix\behaviors\togglebutton.py in __init__(self, **kwargs)
#      82     def __init__(self, **kwargs):
#      83         self._previous_group = None
# ---> 84         super(ToggleButtonBehavior, self).__init__(**kwargs)
#      85
#      86     def on_group(self, *largs):
#
# ~\anaconda3\lib\site-packages\kivy\uix\behaviors\button.py in __init__(self, **kwargs)
#     119             self.min_state_time = float(Config.get('graphics',
#     120                                                    'min_state_time'))
# --> 121         super(ButtonBehavior, self).__init__(**kwargs)
#     122         self.__state_event = None
#     123         self.__touch_time = None
#
# ~\anaconda3\lib\site-packages\kivy\uix\label.py in __init__(self, **kwargs)
#     316     def __init__(self, **kwargs):
#     317         self._trigger_texture = Clock.create_trigger(self.texture_update, -1)
# --> 318         super(Label, self).__init__(**kwargs)
#     319
#     320         # bind all the property for recreating the texture
#
# ~\anaconda3\lib\site-packages\kivy\uix\widget.py in __init__(self, **kwargs)
#     357         if not no_builder:
#     358             rule_children = []
# --> 359             self.apply_class_lang_rules(
#     360                 ignored_consts=self._kwargs_applied_init,
#     361                 rule_children=rule_children)
#
# ~\anaconda3\lib\site-packages\kivy\uix\widget.py in apply_class_lang_rules(self, root, ignored_consts, rule_children)
#     461         .. versionchanged:: 1.11.0
#     462         '''
# --> 463         Builder.apply(
#     464             self, ignored_consts=ignored_consts,
#     465             rule_children=rule_children)
#
# ~\anaconda3\lib\site-packages\kivy\lang\builder.py in apply(self, widget, ignored_consts, rule_children, dispatch_kv_post)
#     539             rule_children = rule_children if rule_children is not None else []
#     540         for rule in rules:
# --> 541             self._apply_rule(
#     542                 widget, rule, rule, ignored_consts=ignored_consts,
#     543                 rule_children=rule_children)
#
# ~\anaconda3\lib\site-packages\kivy\lang\builder.py in _apply_rule(self, widget, rule, rootrule, template_ctx, ignored_consts, rule_children)
#     708             if rule is not None:
#     709                 tb = sys.exc_info()[2]
# --> 710                 raise BuilderException(rule.ctx, rule.line,
#     711                                        '{}: {}'.format(e.__class__.__name__,
#     712                                                        e), cause=tb)
#
# BuilderException: Parser: File "<inline>", line 19:
# ...
#      17:        )
#      18:    color:
# >>   19:        self.text_color_active if self.state == 'down'         else self.text_color_normal
#      20:    on_x: self._trigger_update_tab_indicator()
#      21:    on_width: self._trigger_update_tab_indicator()
# ...
# ValueError: MDTabsLabel.color has an invalid format (got [])
#   File "C:\Users\Vicky\anaconda3\lib\site-packages\kivy\lang\builder.py", line 701, in _apply_rule
#     setattr(widget_set, key, value)
#   File "kivy\weakproxy.pyx", line 35, in kivy.weakproxy.WeakProxy.__setattr__
#   File "kivy\properties.pyx", line 498, in kivy.properties.Property.__set__
#   File "kivy\properties.pyx", line 527, in kivy.properties.Property.set
#   File "kivy\properties.pyx", line 2025, in kivy.properties.ColorProperty.convert
